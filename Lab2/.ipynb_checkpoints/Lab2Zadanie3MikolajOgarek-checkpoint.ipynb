# %% [markdown]
# # BOIKWD
# # Lab 2 AHP - metoda EVM Zadanie 3
#
# ## Mikołaj Ogarek Środa 8:00 grupa 1a

# %% [markdown]
# Wynik:
# <br>Ranking samochodów: <br>
# 1. Samochód2 <br>
# 2. Samochód1 <br>
# 3. Samochód3 <br>

# %%
##########################PRICE RANKING#################################
import numpy as np
from numpy import linalg as LA

#Input data
ccc=np.array([[1,1/3,3],[3,1,5],[1/3,1/5,1]])
ccz=np.array([[1,3,1/3],[1/3,1,1/5],[3,5,1]])


cparc=np.array([[1,1/5],[5,1]])

#List of arrays with parameters
clist = [ccc,ccz]


#Process of finding matrix with normalized eigen vectors of c1,c2...
matrix =[]

for i in clist:
    w, v = LA.eig(i) #eigen values w and corresponding vectors v

    max_eigen_val = max(w)  #finding max eigen_value
    index_max_eigen_val = (w.tolist()).index(max_eigen_val) #index of max eigen value
    eigen_vector = np.transpose((v[:,index_max_eigen_val])).tolist() #finding eigen vector
    
    #process of normalizing eigen vector
    sum_of_eigen = sum(eigen_vector) 
    eigen_vector_normalized=[]
    
    for i in range(len(eigen_vector)):
        eigen_vector_normalized.append(eigen_vector[i]/sum_of_eigen)
    
    #adding eigen vector 
    matrix.append(eigen_vector_normalized)

final_matrix_criterions = np.transpose(matrix)
print("Matrix with eigen vectors of criterions: ")
print(final_matrix_criterions)


#process of finding eigen vector in cparams
w, v = LA.eig(cparc) #eigen walies w and coresponding vectors c

max_eigen_val = max(w) #finding max eigen_value
index_max_eigen_val = (w.tolist()).index(max_eigen_val) #index if max eigen value
eigen_vector = (v[:,index_max_eigen_val]).tolist() #finding eigen vector
    
    
#process of normalizing eigen vector
sum_of_eigen = sum(eigen_vector) 
eigen_vector_normalized=[]
    
for i in range(len(eigen_vector)):
    eigen_vector_normalized.append(eigen_vector[i]/sum_of_eigen)
    
       
print("Eigen vector from parameters comparison - normalized: ")
print(eigen_vector_normalized)

print("Final vector with solution: ")
print(final_matrix_criterions.dot(eigen_vector_normalized))
# Out:
# Matrix with eigen vectors of criterions:
# [[0.25828499+0.j 0.25828499+0.j]
#  [0.63698557+0.j 0.10472943+0.j]
#  [0.10472943+0.j 0.63698557+0.j]]
# Eigen vector from parameters comparison - normalized:
# [0.16666666666666669, 0.8333333333333334]
# Final vector with solution:
# [0.25828499+0.j 0.19343879+0.j 0.54827622+0.j]

# %%
##########################CAPACITY RANKING#################################
import numpy as np
from numpy import linalg as LA

#Input data
ccc=np.array([[1,5,3],[1/5,1,1/3],[1/3,3,1]])
ccz=np.array([[1,1,3],[1,1,3],[1/3,1/3,1]])

cparc=np.array([[1,3],[1/3,1]])

#List of arrays with parameters
clist = [ccc,ccz]


#Process of finding matrix with normalized eigen vectors of c1,c2...
matrix =[]

for i in clist:
    w, v = LA.eig(i) #eigen values w and corresponding vectors v

    max_eigen_val = max(w)  #finding max eigen_value
    index_max_eigen_val = (w.tolist()).index(max_eigen_val) #index of max eigen value
    eigen_vector = np.transpose((v[:,index_max_eigen_val])).tolist() #finding eigen vector
    
    #process of normalizing eigen vector
    sum_of_eigen = sum(eigen_vector) 
    eigen_vector_normalized=[]
    
    for i in range(len(eigen_vector)):
        eigen_vector_normalized.append(eigen_vector[i]/sum_of_eigen)
    
    #adding eigen vector 
    matrix.append(eigen_vector_normalized)

final_matrix_criterions = np.transpose(matrix)
print("Matrix with eigen vectors of criterions: ")
print(final_matrix_criterions)


#process of finding eigen vector in cparams
w, v = LA.eig(cparc) #eigen walies w and coresponding vectors c

max_eigen_val = max(w) #finding max eigen_value
index_max_eigen_val = (w.tolist()).index(max_eigen_val) #index if max eigen value
eigen_vector = (v[:,index_max_eigen_val]).tolist() #finding eigen vector
    
    
#process of normalizing eigen vector
sum_of_eigen = sum(eigen_vector) 
eigen_vector_normalized=[]
    
for i in range(len(eigen_vector)):
    eigen_vector_normalized.append(eigen_vector[i]/sum_of_eigen)
    
       
print("Eigen vector from parameters comparison - normalized: ")
print(eigen_vector_normalized)

print("Final vector with solution: ")
print(final_matrix_criterions.dot(eigen_vector_normalized))
# Out:
# Matrix with eigen vectors of criterions:
# [[0.63698557+0.j 0.42857143+0.j]
#  [0.10472943+0.j 0.42857143+0.j]
#  [0.25828499+0.j 0.14285714+0.j]]
# Eigen vector from parameters comparison - normalized:
# [0.75, 0.25]
# Final vector with solution:
# [0.58488204+0.j 0.18568993+0.j 0.22942803+0.j]

# %%
###########################FINAL RANKING#################################

import numpy as np
from numpy import linalg as LA

#Input data
c1=np.array([[1,0.19/0.26,0.55/0.26],[0.26/0.19,1,0.55/0.19],[0.55/0.26,0.19/0.55,1]])
c2=np.array([[1,3.5/4,4.5/4],[4/3.5,1,4.5/3.5],[4/4.5,3.5/4.5,1]])
c3=np.array([[1,0.19/0.58,0.23/0.58],[0.58/0.19,1,0.23/0.19],[0.58/0.23,0.10/0.23,1]])


cparams=np.array([[1,1/7,3],[7,1,5],[1/3,1/5,1]])


#List of arrays with parameters
clist = [c1,c2,c3]


#Process of finding matrix with normalized eigen vectors of c1,c2...
matrix =[]

for i in clist:
    w, v = LA.eig(i) #eigen values w and corresponding vectors v

    max_eigen_val = max(w)  #finding max eigen_value
    index_max_eigen_val = (w.tolist()).index(max_eigen_val) #index of max eigen value
    eigen_vector = np.transpose((v[:,index_max_eigen_val])).tolist() #finding eigen vector
    
    #process of normalizing eigen vector
    sum_of_eigen = sum(eigen_vector) 
    eigen_vector_normalized=[]
    
    for i in range(len(eigen_vector)):
        eigen_vector_normalized.append(eigen_vector[i]/sum_of_eigen)
    
    #adding eigen vector 
    matrix.append(eigen_vector_normalized)

final_matrix_criterions = np.transpose(matrix)
print("Matrix with eigen vectors of criterions: ")
print(final_matrix_criterions)


#process of finding eigen vector in cparams
w, v = LA.eig(cparams) #eigen walies w and coresponding vectors c

max_eigen_val = max(w) #finding max eigen_value
index_max_eigen_val = (w.tolist()).index(max_eigen_val) #index if max eigen value
eigen_vector = (v[:,index_max_eigen_val]).tolist() #finding eigen vector
    
    
#process of normalizing eigen vector
sum_of_eigen = sum(eigen_vector) 
eigen_vector_normalized=[]
    
for i in range(len(eigen_vector)):
    eigen_vector_normalized.append(eigen_vector[i]/sum_of_eigen)
    
       
print("Eigen vector from parameters comparison - normalized: ")
print(eigen_vector_normalized)

print("Final vector with solution: ")
print(final_matrix_criterions.dot(eigen_vector_normalized))
# Out:
# Matrix with eigen vectors of criterions:
# [[0.30645367 0.32984293 0.16253032]
#  [0.41935765 0.37696335 0.4961452 ]
#  [0.27418869 0.29319372 0.34132448]]
# Eigen vector from parameters comparison - normalized:
# [(0.17017232408137037+0j), (0.7383073751074779+0j), (0.09152030081115177+0j)]
# Final vector with solution:
# [0.31055023+0.j 0.39508525+0.j 0.29436453+0.j]
